# %% [markdown]
# <a href="https://colab.research.google.com/github/bryanf98/IA_2020B/blob/main/DNN_ChangeJob/Flores_ANN_Testeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escuela Politécnica Nacional
#
#
# ---
#
#
# Inteligencia Artificial
#
# Alumno: Bryan Flores Sarango
#
# Fecha:27-01-2021

# %%
from keras.models import load_model
import numpy as np
from google.colab import files

# %% [markdown]
# **Cargamos el Modelo:**

# %%
#Cargar Modelo 1

upload = files.upload()
# Out:
#      <input type="file" id="files-840b59ae-3655-41a6-b93e-797f75d578d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-840b59ae-3655-41a6-b93e-797f75d578d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modeloGuardadoSequential.h5 to modeloGuardadoSequential (1).h5

# %%
model=load_model('modeloGuardadoSequential (1).h5')

# %% [markdown]
# **Cargamos los datos a testear:**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53a83920-109f-4648-b1ae-b78ab5ebc6a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53a83920-109f-4648-b1ae-b78ab5ebc6a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aug_test.csv to aug_test (1).csv

# %% [markdown]
# **Leemos los datos a testear:**

# %%
import pandas as pd
import io
data = pd.read_csv('aug_test.csv')

# %% [markdown]
# **Campos categoricos con Encode:**

# %%
data2=data

from sklearn.preprocessing import LabelEncoder 

caracteristicas=[x for x in data2.columns if data2[x].dtype=="object"]

le=LabelEncoder()

for col in caracteristicas:
    if col in data2.columns:
        i = data2.columns.get_loc(col)
        data2.iloc[:,i] = data2.apply(lambda i:le.fit_transform(i.astype(str)), axis=0, result_type='expand')


#Desde el inicio al final porque no tiene la columna target
X=data2.iloc[:,:].values

X = np.asarray(X).astype('float32')

# %% [markdown]
# **Predecimos los datos con el modelo:**

# %%
Y_predict = model.predict(X)
contador=0
for i in model.predict(X):
  print("La predicción del enrollee_id ",X[contador][0]," es ",i)
  contador=contador+1
# Out:
# La predicción del enrollee_id  32403.0  es  [0.69322497]
# La predicción del enrollee_id  9858.0  es  [0.46084344]
# La predicción del enrollee_id  31806.0  es  [0.7531296]
# La predicción del enrollee_id  27385.0  es  [0.4708497]
# La predicción del enrollee_id  27724.0  es  [0.29888493]
# La predicción del enrollee_id  217.0  es  [0.7614757]
# La predicción del enrollee_id  21465.0  es  [0.515312]
# La predicción del enrollee_id  27302.0  es  [0.2843452]
# La predicción del enrollee_id  12994.0  es  [0.34153423]
# La predicción del enrollee_id  16287.0  es  [0.7258966]
# La predicción del enrollee_id  10856.0  es  [0.23102614]
# La predicción del enrollee_id  9272.0  es  [0.14501512]
# La predicción del enrollee_id  14249.0  es  [0.3832138]
# La predicción del enrollee_id  24372.0  es  [0.07541695]
# La predicción del enrollee_id  14070.0  es  [0.6277772]
# La predicción del enrollee_id  24914.0  es  [0.72732997]
# La predicción del enrollee_id  7865.0  es  [0.39173126]
# ...
